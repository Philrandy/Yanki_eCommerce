# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
yanki_df = pd.read_csv(r'dataset\cleaneddata\yanki_ecommerce.csv')

# %%
yanki_df.tail()
# Out:
#                                   Order_ID  \
# 1015  bb17468a-7648-4974-b3d6-9f9f1a78cb39
# 1016  184827be-c3bd-40a1-a2bb-8b085d58ddc0
# 1017  2dac83f2-fddb-4761-b211-ea716feee91c
# 1018  08341169-2d82-41d4-8273-fda624f99042
# 1019  476f789e-727f-4aad-9395-3d66aec6261a
#
#                                Customer_ID    Customer_Name  \
# 1015  1e75eb3a-9ba5-4ea6-82ec-886abe298058   Jeremy Farrell
# 1016  c53c32ef-2e64-4ac4-ac48-3707ab1ebd1f      Marc Hudson
# 1017  ebc19a03-a32d-4d3c-9976-f30cee3d3a70     Devin Joseph
# 1018  0598403f-7a42-44a9-994e-9f23feb20394  Spencer Elliott
# 1019  8832dd24-c104-475b-8327-d687d3912b58  Jeffrey Jackson
#
#                                 Product_ID Product_Name             Brand  \
# 1015  ad5204d7-e5c2-417c-91f7-5fa07619ef54      officer    Thornton Group
# 1016  0ea15074-b823-4345-924c-aeb9fafe9571        treat   Guzman-Petersen
# 1017  e911b0a9-75fb-4c17-b552-52be0d19f856        watch         Jones-May
# ...

# %%
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Customer_ID         1000 non-null   object
#  2   Customer_Name       1000 non-null   object
#  3   Product_ID          1020 non-null   object
#  4   Product_Name        1020 non-null   object
#  5   Brand               1020 non-null   object
#  6   Category            1020 non-null   object
#  7   Price               1020 non-null   float64
#  8   Quantity            1020 non-null   int64
#  9   Total_Price         1020 non-null   float64
#  10  Order_Date          1020 non-null   object
#  11  Shipping_Address    1020 non-null   object
#  12  City                1020 non-null   object
#  13  State               1020 non-null   object
#  14  Country             1020 non-null   object
# ...

# %% [markdown]
# DATA CLEANING AND TRANSFORMATION

# %%
yanki_df.dropna(subset= ['Order_ID', 'Customer_ID'], inplace= True)

# %%
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Customer_ID         1000 non-null   object
#  2   Customer_Name       1000 non-null   object
#  3   Product_ID          1000 non-null   object
#  4   Product_Name        1000 non-null   object
#  5   Brand               1000 non-null   object
#  6   Category            1000 non-null   object
#  7   Price               1000 non-null   float64
#  8   Quantity            1000 non-null   int64
#  9   Total_Price         1000 non-null   float64
#  10  Order_Date          1000 non-null   object
#  11  Shipping_Address    1000 non-null   object
#  12  City                1000 non-null   object
#  13  State               1000 non-null   object
#  14  Country             1000 non-null   object
# ...

# %%
yanki_df['Order_Date'] = pd.to_datetime(yanki_df['Order_Date'])

# %%
yanki_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'Product_ID',
#        'Product_Name', 'Brand', 'Category', 'Price', 'Quantity', 'Total_Price',
#        'Order_Date', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code', 'Email', 'Phone_Number', 'Payment_Method',
#        'Transaction_Status'],
#       dtype='object')

# %%
Customer_df = yanki_df[['Customer_ID', 'Customer_Name','Email', 'Phone_Number']].copy().drop_duplicates().reset_index(drop=True)

# %%
Customer_df
# Out:
#                               Customer_ID     Customer_Name  \
# 0    e0d6cb3c-c4b0-4cfe-8225-b65d094d2424  Dominic Buchanan
# 1    fa3ca35a-5540-404b-a7eb-9001cdcbd840      Daniel Allen
# 2    7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34    Daniel Schmidt
# 3    4b9b409c-19f2-41c0-bc7c-6556e0647ebb     John Gonzalez
# 4    81b513ad-5c02-48cf-bff0-39e1440c4d22     Amber Benitez
# ..                                    ...               ...
# 985  1e75eb3a-9ba5-4ea6-82ec-886abe298058    Jeremy Farrell
# 986  c53c32ef-2e64-4ac4-ac48-3707ab1ebd1f       Marc Hudson
# 987  ebc19a03-a32d-4d3c-9976-f30cee3d3a70      Devin Joseph
# 988  0598403f-7a42-44a9-994e-9f23feb20394   Spencer Elliott
# 989  8832dd24-c104-475b-8327-d687d3912b58   Jeffrey Jackson
#
#                         Email         Phone_Number
# 0      margaret97@example.com         259.603.6134
# 1        angela55@example.com  +1-869-659-4272x982
# 2         wayne59@example.org     292.840.0975x724
# ...

# %%
products_df = yanki_df[['Product_ID',
       'Product_Name', 'Brand', 'Category', 'Price']].copy().drop_duplicates().reset_index(drop=True)

# %%
products_df.tail()
# Out:
#                                Product_ID Product_Name             Brand  \
# 985  ad5204d7-e5c2-417c-91f7-5fa07619ef54      officer    Thornton Group
# 986  0ea15074-b823-4345-924c-aeb9fafe9571        treat   Guzman-Petersen
# 987  e911b0a9-75fb-4c17-b552-52be0d19f856        watch         Jones-May
# 988  9c9792f9-4dc2-43b2-98f4-e989cf1bdb3a       toward    Richardson PLC
# 989  b835cfa0-70c5-4018-a5e8-50c9d71b5d56          hit  Hamilton-Daniels
#
#         Category   Price
# 985      perfume  118.46
# 986      perfume   91.14
# 987      perfume  246.73
# 988      perfume  647.26
# 989  perfume oil  350.29

# %%
shipping_df = yanki_df[['Customer_ID','Shipping_Address', 'City', 'State', 'Country',
       'Postal_Code']].copy().drop_duplicates().reset_index(drop = True)

# %%
shipping_df
# Out:
#                               Customer_ID  \
# 0    e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 1    fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 2    7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
# 3    4b9b409c-19f2-41c0-bc7c-6556e0647ebb
# 4    81b513ad-5c02-48cf-bff0-39e1440c4d22
# ..                                    ...
# 985  1e75eb3a-9ba5-4ea6-82ec-886abe298058
# 986  c53c32ef-2e64-4ac4-ac48-3707ab1ebd1f
# 987  ebc19a03-a32d-4d3c-9976-f30cee3d3a70
# 988  0598403f-7a42-44a9-994e-9f23feb20394
# 989  8832dd24-c104-475b-8327-d687d3912b58
#
#                                       Shipping_Address             City  \
# 0                     PSC 2224, Box 2284\nAPO AP 65880    Jordanborough
# 1               83909 Johnson Mall\nTranberg, MS 99017    Lake Ginatown
# 2              82101 Johnson Flat\nWest Ryan, MS 29075       Sarahville
# 3            4542 Gary Lane\nSouth Alexander, VI 27671    Lake Michelle
# 4      6794 Caroline Crescent\nEast Karlside, GU 81379       Olsenville
# ...

# %% [markdown]
# ***Resetting Index***

# %%
shipping_df.index.name = 'Shipping_ID'
shipping_df.reset_index()
# Out:
#      Shipping_ID                           Customer_ID  \
# 0              0  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 1              1  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 2              2  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
# 3              3  4b9b409c-19f2-41c0-bc7c-6556e0647ebb
# 4              4  81b513ad-5c02-48cf-bff0-39e1440c4d22
# ..           ...                                   ...
# 985          985  1e75eb3a-9ba5-4ea6-82ec-886abe298058
# 986          986  c53c32ef-2e64-4ac4-ac48-3707ab1ebd1f
# 987          987  ebc19a03-a32d-4d3c-9976-f30cee3d3a70
# 988          988  0598403f-7a42-44a9-994e-9f23feb20394
# 989          989  8832dd24-c104-475b-8327-d687d3912b58
#
#                                       Shipping_Address             City  \
# 0                     PSC 2224, Box 2284\nAPO AP 65880    Jordanborough
# 1               83909 Johnson Mall\nTranberg, MS 99017    Lake Ginatown
# 2              82101 Johnson Flat\nWest Ryan, MS 29075       Sarahville
# ...

# %%
yanki_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'Product_ID',
#        'Product_Name', 'Brand', 'Category', 'Price', 'Quantity', 'Total_Price',
#        'Order_Date', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code', 'Email', 'Phone_Number', 'Payment_Method',
#        'Transaction_Status'],
#       dtype='object')

# %%
order_df = yanki_df[['Order_ID','Customer_ID','Product_ID', 'Quantity', 'Total_Price','Order_Date']].copy().drop_duplicates().reset_index(drop=True)

# %%
order_df.head(20)
# Out:
#                                 Order_ID  \
# 0   e32af09a-b6ab-497e-af3a-331e4d4ed6e7
# 1   86eb8859-14ab-4d4e-9267-c5826f4e0c8e
# 2   7379b560-8897-4623-92a2-523ddcdc43a1
# 3   30c57f86-2fed-43c0-a399-654c2c3bb18d
# 4   41c29d81-9622-43c1-b537-7cdb320d3e6a
# 5   0b8915d7-0614-47c4-88be-25aae8fa477b
# 6   5f05f9e8-57c3-4610-bc41-3c2ccbe3e783
# 7   0abf28e1-7a76-47d5-9d66-2fe2ca920fda
# 8   73129f55-e6fd-45b1-a3ac-fef5fae85dd7
# 9   17647c6b-d1cc-4c86-a1d1-b06641de1574
# 10  a16962fd-0ae2-45cd-bc79-bb5c8fc3c76c
# 11  444dee20-f3e7-4a46-94bf-86f28f3218db
# 12  2bad61d7-1e00-4280-9c63-851860da9097
# 13  f4ca896e-9500-4cad-830b-1d4c264d2e17
# 14  7b10e89e-29e2-49df-951b-cb69f5d63fd7
# 15  596d5762-2de9-4c0f-aa7c-7e6eefefb2fb
# 16  4e830cf0-ea4b-451d-b5ed-753db1dfe1fc
# 17  0e137c97-97a6-4818-848b-de4c93238bb7
# 18  069722e1-6803-47af-9c47-b07bc05c7671
# 19  5c3f5e4c-676e-4223-b23d-74e93cb85325
#
#                              Customer_ID  \
# 0   e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# ...

# %%
payment_df = yanki_df[['Order_ID','Phone_Number', 'Payment_Method',
       'Transaction_Status']].copy().drop_duplicates().reset_index(drop= True)

# %%
payment_df.head(10)
# Out:
#                                Order_ID          Phone_Number Payment_Method  \
# 0  e32af09a-b6ab-497e-af3a-331e4d4ed6e7          259.603.6134     Debit Card
# 1  86eb8859-14ab-4d4e-9267-c5826f4e0c8e   +1-869-659-4272x982    Credit Card
# 2  7379b560-8897-4623-92a2-523ddcdc43a1      292.840.0975x724         PayPal
# 3  30c57f86-2fed-43c0-a399-654c2c3bb18d   +1-643-561-3912x262         PayPal
# 4  41c29d81-9622-43c1-b537-7cdb320d3e6a            3424148376         PayPal
# 5  0b8915d7-0614-47c4-88be-25aae8fa477b    833-392-3750x99267     Debit Card
# 6  5f05f9e8-57c3-4610-bc41-3c2ccbe3e783          824-668-9191         PayPal
# 7  0abf28e1-7a76-47d5-9d66-2fe2ca920fda       +1-683-714-3681         PayPal
# 8  73129f55-e6fd-45b1-a3ac-fef5fae85dd7  +1-261-681-8748x0788         PayPal
# 9  17647c6b-d1cc-4c86-a1d1-b06641de1574       +1-269-289-6161         PayPal
#
#   Transaction_Status
# 0          completed
# 1          completed
# 2            pending
# 3          completed
# ...

# %%
# Saving files

# %%
payment_df.to_csv(r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Payment.csv', index= False)
Customer_df.to_csv(r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Customer.csv', index= False)
order_df.to_csv(r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Orders.csv', index= False)
shipping_df.to_csv(r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Shipping_Details.csv', index= False)
products_df.to_csv(r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Products.csv', index= False)

# %% [markdown]
# **Creating a DataBase for Postgres**

# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
def db_connection():
    connection = psycopg2.connect(
        host='localhost',
        database ='Yanki_eCommerce',
        user = 'postgres',
        password = 'root'

    )
    return connection

# %%
conn = db_connection()

# %% [markdown]
# ### Creating sql tables

# %%
def create_tables():
    conn = db_connection()
    cursor = conn.cursor()
    create_table_query = '''
                                CREATE SCHEMA IF NOT EXISTS yanki;

                                DROP TABLE IF EXISTS yanki.customers CASCADE;
                                DROP TABLE IF EXISTS yanki.products CASCADE;
                                DROP TABLE IF EXISTS yanki.orders CASCADE;
                                DROP TABLE IF EXISTS yanki.payment_method CASCADE;
                                DROP TABLE IF EXISTS yanki.shipping CASCADE;
                                

                                CREATE TABLE IF NOT EXISTS yanki.customers(
                                Customer_ID UUID Primary Key,
                                Customer_Name TEXT,
                                Email TEXT,
                                Phone TEXT
                                );

                                CREATE TABLE IF NOT EXISTS yanki.products(
                                Product_ID UUID Primary Key,
                                Product_Name TEXT,
                                Brand TEXT,
                                Category TEXT,
                                Price FLOAT
                                );

                                CREATE TABLE IF NOT EXISTS yanki.Shipping(
                                Shipping_ID Serial Primary Key,
                                Customer_ID UUID,
                                Shipping_Address TEXT,
                                City TEXT,
                                State TEXT,
                                Country TEXT,
                                Postal_Code INTEGER,
                                Foreign Key (Customer_ID)references yanki.customers(Customer_ID)
                                );
                                
                                CREATE TABLE IF NOT EXISTS yanki.orders(
                                Order_ID UUID Primary Key,
                                Customer_ID UUID ,
                                Product_ID UUID,
                                Quantity INTEGER,
                                Total_Price Float,
                                Order_Date Date,

                                Foreign Key (Customer_ID)references yanki.customers(Customer_ID),
                                Foreign Key (Product_ID)references yanki.products(Product_ID)
                                );

                                CREATE TABLE IF NOT EXISTS yanki.payment(
                                Order_ID UUID Primary Key,
                                Phone_Number TEXT,
                                Payment_Method TEXT,
                                Transaction_Status TEXT,
                                
                                Foreign Key (Order_ID)references yanki.orders(Order_ID)
                               
                                );'''
    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

# %%
display(payment_df.columns)
# Out:
# Index(['Order_ID', 'Phone_Number', 'Payment_Method', 'Transaction_Status'], dtype='object')

# %%
display(payment_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            990 non-null    object
#  1   Phone_Number        990 non-null    object
#  2   Payment_Method      990 non-null    object
#  3   Transaction_Status  990 non-null    object
# dtypes: object(4)
# memory usage: 31.1+ KB
# None

# %%
yanki_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'Product_ID',
#        'Product_Name', 'Brand', 'Category', 'Price', 'Quantity', 'Total_Price',
#        'Order_Date', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code', 'Email', 'Phone_Number', 'Payment_Method',
#        'Transaction_Status'],
#       dtype='object')

# %%
create_tables()

# %%
import csv
def load_data(csv_path):
    conn = db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''
                           INSERT INTO yanki.customers(Customer_ID, Customer_Name, Email, Phone)
                            VALUES (%s,%s,%s,%s);''',
                            row
                           
                           
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'C:\Users\iamin\OneDrive\Desktop\yanki_ecommerce\Yanki_eCommerce\dataset\cleaneddata\ Customer.csv'
load_data(csv_file_path)

# %%
def load_data(csv_path):
    conn = db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''
                           INSERT INTO yanki.Products(Product_ID, Product_Name, Brand, Category, Price)
                            VALUES (%s,%s,%s,%s,%s);''',
                            row
                           
                           
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'dataset\cleaneddata\ Products.csv'
load_data(csv_file_path)

# %%
def load_data(csv_path):
    conn =db_connection()
    cursor = conn.cursor()
    with open (csv_path, 'r') as file:
        reader =csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''
                            insert into yanki.Orders(Order_ID, Customer_ID, Product_ID, Quantity, Total_Price, Order_Date)
                        values(%s,%s,%s,%s,%s,%s);''',
                        row
                        )
    conn.commit()
    cursor.close()
    conn.close()

csv_file_path = r'dataset\cleaneddata\ Orders.csv'
load_data(csv_file_path)

# %%
def load_csv_data(csv_path):
    conn = db_connection()
    cursor = conn.cursor()
    with open (csv_path, 'r') as file:
        readers = csv.reader(file)
        next(readers)
        for row in readers:
            cursor.execute('''
                        insert into yanki.payment(Order_ID, Phone_Number, Payment_Method, Transaction_Status)
                        values(%s,%s,%s,%s);''',
                        row
                        )
    conn.commit()
    cursor.close()
    conn.close()

csv_location = r'dataset\cleaneddata\ Payment.csv'
load_csv_data(csv_location)

# %%
def load_file(csv_path):
    conn= db_connection()
    cursor = conn.cursor()
    with open (csv_path, 'r') as file:
        readers =csv.reader(file)
        next(readers)
        for row in readers:
            cursor.execute('''
                            insert into yanki.shipping(Customer_ID, Shipping_Address, City, State, Country, Postal_Code)
                           values(%s,%s,%s,%s,%s,%s);''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
path_of_csv = r'dataset\cleaneddata\ Shipping_Details.csv'
load_file(path_of_csv)

# %%
display(shipping_df.columns)
# Out:
# Index(['Customer_ID', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code'],
#       dtype='object')

# %%
Customer_df
# Out:
#                               Customer_ID     Customer_Name  \
# 0    e0d6cb3c-c4b0-4cfe-8225-b65d094d2424  Dominic Buchanan
# 1    fa3ca35a-5540-404b-a7eb-9001cdcbd840      Daniel Allen
# 2    7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34    Daniel Schmidt
# 3    4b9b409c-19f2-41c0-bc7c-6556e0647ebb     John Gonzalez
# 4    81b513ad-5c02-48cf-bff0-39e1440c4d22     Amber Benitez
# ..                                    ...               ...
# 985  1e75eb3a-9ba5-4ea6-82ec-886abe298058    Jeremy Farrell
# 986  c53c32ef-2e64-4ac4-ac48-3707ab1ebd1f       Marc Hudson
# 987  ebc19a03-a32d-4d3c-9976-f30cee3d3a70      Devin Joseph
# 988  0598403f-7a42-44a9-994e-9f23feb20394   Spencer Elliott
# 989  8832dd24-c104-475b-8327-d687d3912b58   Jeffrey Jackson
#
#                         Email         Phone_Number
# 0      margaret97@example.com         259.603.6134
# 1        angela55@example.com  +1-869-659-4272x982
# 2         wayne59@example.org     292.840.0975x724
# ...
